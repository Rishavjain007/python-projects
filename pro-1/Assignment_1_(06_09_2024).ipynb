# %% [markdown]
# #Assignment 1 (06/09/2024)

# %% [markdown]
# Q1: Given a list of items with mixed data types:
#
# my_list = [25, "Python", 5.8, True, [1, 2, 3]]
# Write a Python program to print the type of each element in the list.

# %% [markdown]
# Q2: Write a Python program to convert a float number 25.85 to an integer and a string, and then print the results with their types.

# %% [markdown]
# Q3: Write a Python program that accepts a number from the user and checks whether the number is positive, negative, or zero using if-elif-else.

# %% [markdown]
# Q4: Write a Python program to print all even numbers between 1 and 50 using a for loop.

# %% [markdown]
# #Question 5
# ![Screenshot 2024-09-06 133547.png](data:image/png;base64,...)

# %% [markdown]
# #question 6
# ![Screenshot 2024-09-06 134943.png](data:image/png;base64,...)

# %% [markdown]
# #Question 7
# ![Screenshot 2024-09-06 135526.png](data:image/png;base64,...)

# %% [markdown]
# #Question 8
# Find the factorial of a given number
# Write a Python program to use for loop to find the factorial of a given number.
#
# The factorial (symbol: !) means multiplying all numbers from the chosen number down to 1.
#
# For example, a factorial of 5! is 5 × 4 × 3 × 2 × 1 = 120

# %% [markdown]
# # Question 9
# Reverse a integer number(without using reverse or sort)
# Given:
#
# 76542
#
# Expected output:
#
# 24567

# %% [markdown]
# #question 10
# Calculate the cube of all numbers from 1 to a given number
#
# Write a Python program to print the cube of all numbers from 1 to a given number
#
# Given:
#
# input_number = 7
