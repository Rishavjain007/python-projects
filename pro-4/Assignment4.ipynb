# %% [markdown]
# ## create Assignment with using good skills and good to watch.
# ## create with idea from diff. online source make it good.

# %% [markdown]
# 1. what is SDLC? explain each and everything (300)

# %% [markdown]
# ans=1
#
# The SDLC is essential for structured software development, enhancing project management, and ensuring quality outcomes. By following these phases, organizations can effectively manage the complexities of software development, leading to successful project completion.
#
#  Here’s an overview of each phase:
#
# 1. Planning:
#
# This initial stage involves defining the project’s goals, scope, resources, and timelines. Stakeholders identify the needs and requirements, and feasibility studies assess potential risks and challenges. A project plan is created to guide the development process.
#
# 2. Requirements Gathering and Analysis:
#
# In this phase, detailed requirements are gathered through interviews, surveys, and analysis of existing systems. Requirements are categorized into functional (what the system should do) and non-functional (how the system performs). This leads to the creation of a Software Requirements Specification (SRS) document.
#
# 3. Design:
#
# The design phase translates requirements into a blueprint for the software. This involves architectural design (overall structure) and detailed design (specific components). Tools like UML diagrams may be used. The goal is to create a comprehensive design document that guides developers.
#
# 4. Development:
#
# In this phase, developers write the actual code based on the design specifications. This is often the longest phase of the SDLC. Coding standards and best practices are followed to ensure quality. Version control systems are typically used to manage code changes.
#
# 5. Testing:
#
# Testing is crucial to ensure that the software meets all requirements and is free of defects. Various types of testing are performed, including unit testing (individual components), integration testing (combined components), system testing (entire system), and user acceptance testing (UAT). Issues found are reported and fixed.
#
# 6. Deployment:
#
# Once testing is complete, the software is deployed to the production environment. This may involve installation, configuration, and data migration. Depending on the organization, deployment can be done all at once (big bang) or in stages (phased rollout).
#
# 7. Maintenance:
#
# After deployment, the software enters the maintenance phase. This involves ongoing support, bug fixes, updates, and enhancements based on user feedback. Maintenance ensures that the software continues to meet user needs and adapts to changing environments.

# %% [markdown]
# 2. what is matrix ? describe each and everything(500 words)

# %% [markdown]
# ans=2
#
# Matrices are powerful mathematical tools that enable complex computations across various fields. Their structured format allows for efficient data manipulation and representation, making them essential in both theoretical and practical applications. Understanding matrices and their operations is crucial for anyone involved in mathematics, science, or engineering
#
# A matrix is usually denoted by a capital letter (e.g.A,B).
# The size or dimension of a matrix is defined by the number of rows and columns it contains, expressed as m*n (m rows and n columns).
#  For example,3×2 matrix has three rows and two columns.
#
# 1. Types of Matrices
#
# Row Matrix:
#  A matrix with a single row.
# A=[1,2,3] (1 x 3 matrix).
#
# Column Matrix:
#  A matrix with a single column.
#
# Square Matrix:
#  A matrix where the number of rows equals the number of columns.
#
# Diagonal Matrix:
#  A square matrix where all off-diagonal elements are zero.
#
# Identity Matrix:
# A special type of diagonal matrix where all diagonal elements are 1.
#
# Zero Matrix:
#  A matrix where all elements are zero.
#
# Symmetric Matrix:
#  A square matrix that is equal to its transpose.
#
# Transposed Matrix:
#  The matrix obtained by swapping the rows and columns of a matrix.
#
#
#
# 2. Matrix Operations:
#
# Matrices can be manipulated through various operations:
#
# Addition:
#  Two matrices of the same dimension can be added by adding their corresponding elements.
#
# Subtraction:
#  Similar to addition, matrices of the same dimension can be subtracted.
#
# Scalar Multiplication:
#  Each element of a matrix can be multiplied by a scalar (a constant).
#
# Matrix Multiplication:
#  The product of two matrices is calculated by taking the dot product of rows and columns. This operation is only defined when the number of columns in the first matrix equals the number of rows in the second.

# %% [markdown]
# 3. Describe importance of Linkdin ? (300 words)

# %% [markdown]
# ans=3
#
# LinkedIn is a vital tool for professionals seeking to advance their careers, expand their networks, and stay informed about industry developments. Its multifaceted features make it indispensable for both job seekers and employers alike.
#
# Some importance of LinkedIn are as follows:
#
# 1. Professional Networking:
#
# It allows users to connect with industry professionals, colleagues, and potential employers.
# This networking capability can lead to job opportunities, collaborations, and valuable industry insights.
#
# 2. Job Search:
#
# The platform hosts millions of job listings, making it a valuable resource for job seekers. Users can apply for jobs directly through LinkedIn, receive job recommendations based on their profiles, and even get referrals from connections.
#
# 3. Personal Branding;
#
# It enables individuals to create a professional online presence.
# Users can showcase their skills, experiences, and accomplishments through detailed profiles, including recommendations and endorsements, which enhance credibility and visibility.
#
# 4. Industry Insights:
#
# By following companies and industry leaders, users can stay updated on trends, news, and developments in their fields. This information is vital for career growth and informed decision-making.
#
# 5. Learning Opportunities:
#
# It offers a vast array of courses and tutorials, allowing users to acquire new skills or enhance existing ones. This commitment to continuous learning is essential in a rapidly changing job market.
#
# 6. Recruitment Tool:
#
# For employers,It serves as a powerful recruitment platform.
# It allows companies to find and engage with potential candidates through targeted searches, job postings, and outreach.

# %% [markdown]
# 4. Describe OOPs and its type with example.(500 words)

# %% [markdown]
# ans=4
#
#  Object-Oriented Programming (OOP) is a programming that uses "objects" to design software. Objects represent real-world entities and can contain both data and methods.OOP enhances software development through its principles, enabling developers to create more organized, maintainable, and scalable code.
#   The main principles of OOP include encapsulation, inheritance, polymorphism, and abstraction. Each of these concepts helps in building robust and reusable software.
#
# 1. Encapsulation:
#  It binds data (attributes) and methods (functions) that operate on given data into a single unit or class. This helps protect the internal state of an object from unintended interference and misuse.
#
# Example,
# A BankAccount class can have attributes like 'balance' and methods like deposit() and withdraw(), ensuring that any changes to the balance occur through defined methods, maintaining control over how the data is accessed or modified.
#
# 2. Inheritance:
# It allows a class (child class) to inherit attributes and methods from another class (parent class). This promotes code reuse and establishes a relationship between classes.
#
# Example,
# If you have a base class Animal, you can create subclasses like Dog and Cat that inherit common behaviors but also implement their specific functionalities.
#
# 3. Polymorphism:
# It allows methods to do different things based on the object that it is acting upon, even if they share the same name.
# This can be achieved through method overriding (as seen in the speak method of the Dog and Cat classes) or method overloading (same method name with different parameters).
#
# 4. Abstraction:
# It involves hiding complex implementation details and showing only the essential features of an object to the user.
# It can be achieved using abstract classes.

# %%
#EXAMPLES
#1
class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount

    def get_balance(self):
        return self.__balance
    
#2
# 
class Animal:
    def speak(self):
        return "Some sound"

class Dog(Animal):
    def speak(self):
        return "Bark"

class Cat(Animal):
    def speak(self):
        return "Meow"



#3
# 
def animal_sound(animal):
    print(animal.speak())

my_dog = Dog()
my_cat = Cat()
animal_sound(my_dog)
animal_sound(my_cat)

# %% [markdown]
#   6. Create Snake Game in Python – Snake Game Program using Pygame (use online help to create code and explain concept in text)

# %%
import pygame
import time
import random

# Initialize Pygame
pygame.init()

# Define colors
white = (255, 255, 255)
yellow = (255, 255, 102)
black = (0, 0, 0)
red = (213, 50, 80)
green = (0, 255, 0)
blue = (50, 153, 213)

# Game window dimensions
width = 600
height = 400

# Create the display
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption('Snake Game')

# Clock to control the game's frame rate
clock = pygame.time.Clock()

# Snake parameters
snake_block = 10
snake_speed = 15

# Font styles
font_style = pygame.font.SysFont("bahnschrift", 25)
score_font = pygame.font.SysFont("comicsansms", 35)

def display_score(score):
    score_display = score_font.render(f"Score: {score}", True, black)
    screen.blit(score_display, [0, 0])

def draw_snake(snake_block, snake_list):
    for x in snake_list:
        pygame.draw.rect(screen, black, [x[0], x[1], snake_block, snake_block])

def message(msg, color):
    mesg = font_style.render(msg, True, color)
    screen.blit(mesg, [width / 6, height / 3])

def game_loop():
    game_over = False
    game_close = False

    x1 = width / 2
    y1 = height / 2

    x1_change = 0
    y1_change = 0

    snake_list = []
    snake_length = 1

    foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
    foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0

    while not game_over:

        while game_close == True:
            screen.fill(blue)
            message("You Lost! Press C-Play Again or Q-Quit", red)
            display_score(snake_length - 1)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        game_loop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x1_change = -snake_block
                    y1_change = 0
                elif event.key == pygame.K_RIGHT:
                    x1_change = snake_block
                    y1_change = 0
                elif event.key == pygame.K_UP:
                    y1_change = -snake_block
                    x1_change = 0
                elif event.key == pygame.K_DOWN:
                    y1_change = snake_block
                    x1_change = 0

        if x1 >= width or x1 < 0 or y1 >= height or y1 < 0:
            game_close = True

        x1 += x1_change
        y1 += y1_change
        screen.fill(blue)
        pygame.draw.rect(screen, green, [foodx, foody, snake_block, snake_block])
        snake_head = []
        snake_head.append(x1)
        snake_head.append(y1)
        snake_list.append(snake_head)
        if len(snake_list) > snake_length:
            del snake_list[0]

        for x in snake_list[:-1]:
            if x == snake_head:
                game_close = True

        draw_snake(snake_block, snake_list)
        display_score(snake_length - 1)

        pygame.display.update()

        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
            foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0
            snake_length += 1

        clock.tick(snake_speed)

    pygame.quit()
    quit()

game_loop()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Explanation of Code:
#
# Initialization:
# We import Pygame and initialize it.
# We define colors, game dimensions, and create a display window.
#
# Functions:
#
# 1. display_score:
# Displays the current score on the screen.
#
# 2. draw_snake:
# Draws the snake using rectangles.
#
# 3. message:
# Displays a message when the game ends.
#
# 4. game_loop:
# Contains the main logic of the game, including input handling, updating the snake's position, and checking for collisions.
#
# 5. Game Logic:
# The snake moves in response to arrow key inputs. When it eats food, its length increases, and the food reappears at a random location.
# The game checks for collisions with walls or itself.
#
# 6. Game Over Handling:
# When the game ends, it displays a message and waits for the user to either restart or quit.

# %% [markdown]
# Line-by-Line Explanation
# Import Libraries:
#
# <!-- import pygame
# import time
# import random -->
#
# pygame:
# The library used for game development.
#
# time:
# Used for timing functions (not extensively used here).
#
# random:
# Used to generate random positions for the food.
#
#
# Initialize Pygame:
# <!--
# pygame.init() -->
# Initializes all Pygame modules.
#
#
# Define Colors:
#
# white = (255, 255, 255)
# <!-- black = (0, 0, 0)
# red = (213, 50, 80)
# green = (0, 255, 0)
# blue = (50, 153, 213) -->
# Colors are defined in RGB format.
#
#
# Game Window Dimensions:
#
# <!-- width = 600
# height = 400 -->
#
# Sets the width and height for the game window.
#
#
# Create Display:
#
# <!-- screen = pygame.display.set_mode((width, height))
# pygame.display.set_caption('Simple Snake Game') -->
#
# Creates the game window and sets its title.
#
#
# Clock for Frame Rate:
# <!--
# clock = pygame.time.Clock() -->
#
# Used to control how fast the game runs.
#
#
# Snake Parameters:
#
# <!-- snake_block = 10
# snake_speed = 15 -->
#
# snake_block:
# Size of each block of the snake.
#
# snake_speed:
# Control how fast the snake moves.
#
#
# Draw Snake Function:
#
# <!-- def draw_snake(snake_list):
#     for x in snake_list:
#         pygame.draw.rect(screen, black, [x[0], x[1], snake_block, snake_block]) -->
#
#
# Takes a list of snake segments and draws them on the screen.
#
#
# Main Game Function:
#
# <!-- def game_loop(): -->
#
# Contains the main logic of the game.
#
#
# Game State Variables:
#
# <!-- game_over = False
# game_close = False -->
#
# Flags to manage the game state.
#
#
# Initial Snake Position:
#
# <!-- x1 = width / 2
# y1 = height / 2 -->
#
# Places the snake in the center of the window.
#
#
# Snake Movement Changes:
#
# <!-- x1_change = 0
# y1_change = 0 -->
#
# Initializes changes in position for the snake.
#
#
# Snake and Food Initialization:
#
# <!-- snake_list = []
# snake_length = 1
# foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
# foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0 -->
#
# Creates an empty list for the snake's segments and sets the initial food position randomly.
#
#
# Game Loop:
#
# <!-- while not game_over: -->
#
# Continues until the game is over.
#
#
# Game Over Logic:
# <!--
# while game_close: -->
#
# Handles what happens when the game is lost.
#
#
# Event Handling:
# <!--
# for event in pygame.event.get(): -->
#
# Checks for user inputs and updates the game state based on key presses.
#
#
# Movement Input:
#
# <!-- if event.type == pygame.KEYDOWN: -->
#
# Checks for key presses (left, right, up, down) to change the snake's direction.
#
#
# Collision Detection:
#
# <!-- if x1 >= width or x1 < 0 or y1 >= height or y1 < 0:
#     game_close = True -->
#
#
# Checks if the snake hits the walls.
#
#
# Update Snake Position:
#
# <!-- x1 += x1_change
# y1 += y1_change -->
#
# Updates the snake's head position based on the direction.
#
# Draw Food:
#
# <!-- pygame.draw.rect(screen, green, [foodx, foody, snake_block, snake_block]) -->
#
# Draws the food on the screen.
#
#
# Update Snake Length:
#
# <!-- snake_head = [x1, y1]
# snake_list.append(snake_head)
# if len(snake_list) > snake_length:
#     del snake_list[0] -->
#
# Adds the new head position to the snake's body and removes the tail segment if the snake length exceeds its current length.
#
#
# Self-Collision Check:
#
# <!-- for segment in snake_list[:-1]:
#     if segment == snake_head:
#         game_close = True -->
#
# Checks if the snake has collided with itself.
#
#
# Draw the Snake:
#
# <!-- draw_snake(snake_list)
# pygame.display.update() -->
#
# Calls the function to draw the snake and updates the display.
#
#
# Food Collision Check:
#
# <!-- if x1 == foodx and y1 == foody: -->
#
# If the snake eats the food, generate new food and increase the snake's length.
#
#
# Control Frame Rate:
#
# <!-- clock.tick(snake_speed) -->
#
# Regulates how fast the game updates.
#
#
# Quit Pygame:
#
# <!-- pygame.quit() -->

# %% [markdown]
# 7. Random Password Generator using Python((use online help to create code and explain concept in text)

# %%
import random
import string

def generate_password(length=12):
    if length < 6:
        raise ValueError("Password length should be at least 6 characters.")

    # Define character sets
    lowercase = string.ascii_lowercase
    uppercase = string.ascii_uppercase
    digits = string.digits
    special_characters = string.punctuation

    # Ensure at least one character from each category is included
    password = [
        random.choice(lowercase),
        random.choice(uppercase),
        random.choice(digits),
        random.choice(special_characters)
    ]

    # Fill the rest of the password length with random choices from all categories
    all_characters = lowercase + uppercase + digits + special_characters
    password += random.choices(all_characters, k=length - 4)

    # Shuffle the password to ensure random order
    random.shuffle(password)

    # Convert list to string and return
    return ''.join(password)

# Example usage
print("Random Password:", generate_password(12))
# Out:
# Random Password: wXW!,49OeH99

# %% [markdown]
# Character Sets:
#
# Uppercase Letters:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
#
# Lowercase Letters:
# abcdefghijklmnopqrstuvwxyz
#
# Digits:
#  0123456789
#
# Special Characters:
#  !@#$%^&*()-_=+[]{}|;:,.<>?/
#
#
# Randomization:
#
# We will use Python's random module to randomly select characters from these sets to build the password.
# Length of the Password:
#
# The user can specify how long the password should be, which adds flexibility.
